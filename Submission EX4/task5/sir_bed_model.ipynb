# %%
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
from matplotlib import cm
from plot import *

from sir_model import *
from scipy.integrate import solve_ivp

# %%
# plot sir trajectory with 3 initial condition

SIM0_list0 = [[195.7, 0.03, 3.92]] 
SIM0_list1 = [[195.3,0.052,4.4]] 
SIM0_list2 = [[193,0.08,6.21]]

# SIM0_list = [[195.7, 0.03, 3.92],[195.3,0.052,4.4],[193,0.08,6.21]] # plot all initial condition in one figure

# simulate with different b

for b in np.arange(0.010,0.031,0.001):
    b = np.round(b,3)
    sir_trajectory(SIM0_list0,True,'b',b)
    sir_trajectory(SIM0_list1,True,'b',b)
    sir_trajectory(SIM0_list2,True,'b',b)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#      12 sir_trajectory(SIM0_list0,True,'b',b)
#      13 sir_trajectory(SIM0_list1,True,'b',b)
# ---> 14 sir_trajectory(SIM0_list2,True,'b',b)
#
# File ~/Documents/mlcms/Submission EX4/task5/plot.py:133, in sir_trajectory(SIM0_list, show_traj, para, b, mu1)
#     131   ax.set_title('SIR trajectory for '+para+'='+str(bif_para))
#     132   fig.tight_layout()
# --> 133   plt.savefig('SIR trajectory for '+para+'='+str(bif_para)+'.png')
#     134 plt.show()
#
# File ~/anaconda3/envs/CMS/lib/python3.11/site-packages/matplotlib/pyplot.py:1119, in savefig(*args, **kwargs)
#    1116 fig = gcf()
#    1117 # savefig default implementation has no return, so mypy is unhappy
#    1118 # presumably this is here because subclasses can return?
# -> 1119 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
# ...

# %%
# Bonus: use mu1 as the bifurcation parameter and show backward bifurcation between mu1 equal to 10.400 and 10.401
# create a grid for initial points
SIM0_list=[]
x_range = np.linspace(190, 210, num=5)
y_range = np.linspace(0, 0.25, num=5)
z_range = np.linspace(0, 8, num=5)

xyz_grid = []
for x in x_range:
    for y in y_range:
        for z in z_range:
            SIM0_list.append([x, y, z])
# whether show the trajectory or just show the initial and final points
show_traj = False
# simulate with different mu1
for mu1 in np.arange(10.40,10.402,0.001):
    mu1 = np.round(mu1,3)
    sir_trajectory(SIM0_list,show_traj,'mu1',0.06,mu1)
sir_trajectory(SIM0_list,show_traj,'mu1',0.06,mu1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 17
#      15 for mu1 in np.arange(10.40,10.402,0.001):
#      16     mu1 = np.round(mu1,3)
# ---> 17     sir_trajectory(SIM0_list,show_traj,'mu1',0.06,mu1)
#      18 sir_trajectory(SIM0_list,show_traj,'mu1',0.06,mu1)
#
# File ~/Documents/mlcms/Submission EX4/task5/plot.py:134, in sir_trajectory(SIM0_list, show_traj, para, b, mu1)
#     132   fig.tight_layout()
#     133   plt.savefig('SIR trajectory for '+para+'='+str(bif_para)+'.png')
# --> 134 plt.show()
#
# File ~/anaconda3/envs/CMS/lib/python3.11/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# ...
