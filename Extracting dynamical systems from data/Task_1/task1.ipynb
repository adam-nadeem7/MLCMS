# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import lstsq
from approximate_functions_and_plot import *
data_l=np.loadtxt('./linear_function_data.txt')
data_nl=np.loadtxt('./nonlinear_function_data.txt')

# %%
# linear_approximate for two dataset
linear_approximate(data_l)
linear_approximate(data_nl)
# Out:
# Approximate linear function: y = 0.75x + 0.00
# Approximate linear function: y = 0.03x + 0.11

# %%
# data_nl is a 2D NumPy array with two columns, x and fx
x, fx = data_nl.T
# set a range from which select L and epsilon
l_rang=(5,15)
e_range=(0.6,1.6)
# plot residual with diffrernt L and epsilon
plot_find_para(l_rang,e_range,x, fx)
# get cefficient and residual
coe,res = ls_rbf(x, fx, 11, 1.1)
# plot with the best pair of L and epsilon

plot_rbf(x, fx, 11, 1.1,coe)

# %%
# data_nl is a 2D NumPy array with two columns, x and fx
x, fx = data_l.T
# # set a range from which select L and epsilon
# l_rang=(5,15)
# e_range=(0.6,1.6)
# # plot residual with diffrernt L and epsilon
# plot_find_para(l_rang,e_range,x, fx)
# get cefficient and residual
coe,res = ls_rbf(x, fx,5 , 1.1)
# plot with the best pair of L and epsilon

plot_rbf(x, fx, 5, 1.1,coe)
